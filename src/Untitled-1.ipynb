# %%
import pandas as pd
import sys, os
sys.path.append(os.path.abspath(".."))

def read_csv_from_s3(s3_path: str) -> pd.DataFrame:
    # Uses pandas + s3fs (ensure s3fs installed)
    return pd.read_csv(s3_path)

# %%
import sys, os
from src.data.s3_utils import read_csv_from_s3
df = read_csv_from_s3("s3://mybucket-training-98765/AB_NYC_2019.csv")
print(df.shape)
df.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[32], line 2
#       1 import sys, os
# ----> 2 from src.data.s3_utils import read_csv_from_s3
#       3 df = read_csv_from_s3("s3://mybucket-training-98765/AB_NYC_2019.csv")
#       4 print(df.shape)
#
# ModuleNotFoundError: No module named 'src'

# %%
if __name__ == "__main__":
    df = read_listings_s3("s3://mybucket-training-98765/AB_NYC_2019.csv")
    print(df.shape)
    print(df.columns[:20])
# Out:
# (48895, 16)
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')
